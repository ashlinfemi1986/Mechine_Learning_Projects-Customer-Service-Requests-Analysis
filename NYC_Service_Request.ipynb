# %% [markdown]
# # Customer Service Requests Analysis

# %% [markdown]
# ### Exploratory Data Analysis

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
data= 'nyc.csv'
df = pd.read_csv(data)
df.head(3)
# Out:
#    Unique Key            Created Date             Closed Date Agency  \
# 0    12822544  01/01/2009 12:00:00 AM  01/07/2009 12:00:00 AM    HPD
# 1    12818524  01/01/2009 12:00:00 AM                     NaN  DOHMH
# 2    12823061  01/01/2009 12:00:00 AM  01/01/2009 12:00:00 AM    DOT
#
#                                          Agency Name  \
# 0  Department of Housing Preservation and Develop...
# 1            Department of Health and Mental Hygiene
# 2                       Department of Transportation
#
#              Complaint Type         Descriptor               Location Type  \
# 0                   HEATING               HEAT        RESIDENTIAL BUILDING
# 1                   Smoking  Smoking Violation  Restaurant/Bar/Deli/Bakery
# 2  Traffic Signal Condition         Controller                         NaN
#
#   Incident Zip      Incident Address      Street Name   Cross Street 1  \
# 0        11225    55 WINTHROP STREET  WINTHROP STREET  FLATBUSH AVENUE
# ...

# %%
#set unique key as index
#df = pd.read_csv(data,index_col='Unique Key')
# Out:
# C:\Users\Ashlin Femi R N\Anaconda3\lib\site-packages\numpy\lib\arraysetops.py:569: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   mask |= (ar1 == a)

# %%
df.head()
# Out:
#    Unique Key            Created Date             Closed Date Agency  \
# 0    12822544  01/01/2009 12:00:00 AM  01/07/2009 12:00:00 AM    HPD
# 1    12818524  01/01/2009 12:00:00 AM                     NaN  DOHMH
# 2    12823061  01/01/2009 12:00:00 AM  01/01/2009 12:00:00 AM    DOT
# 3    12823062  01/01/2009 12:00:00 AM  01/01/2009 12:00:00 AM    DOT
# 4    12823063  01/01/2009 12:00:00 AM  01/01/2009 12:00:00 AM    DOT
#
#                                          Agency Name  \
# 0  Department of Housing Preservation and Develop...
# 1            Department of Health and Mental Hygiene
# 2                       Department of Transportation
# 3                       Department of Transportation
# 4                       Department of Transportation
#
#              Complaint Type         Descriptor               Location Type  \
# 0                   HEATING               HEAT        RESIDENTIAL BUILDING
# 1                   Smoking  Smoking Violation  Restaurant/Bar/Deli/Bakery
# ...

# %%
df.shape
# Out:
# (1783133, 52)

# %%
df.columns
# Out:
# Index(['Unique Key', 'Created Date', 'Closed Date', 'Agency', 'Agency Name',
#        'Complaint Type', 'Descriptor', 'Location Type', 'Incident Zip',
#        'Incident Address', 'Street Name', 'Cross Street 1', 'Cross Street 2',
#        'Intersection Street 1', 'Intersection Street 2', 'Address Type',
#        'City', 'Landmark', 'Facility Type', 'Status', 'Due Date',
#        'Resolution Action Updated Date', 'Community Board', 'Borough',
#        'X Coordinate (State Plane)', 'Y Coordinate (State Plane)',
#        'Park Facility Name', 'Park Borough', 'School Name', 'School Number',
#        'School Region', 'School Code', 'School Phone Number', 'School Address',
#        'School City', 'School State', 'School Zip', 'School Not Found',
#        'School or Citywide Complaint', 'Vehicle Type', 'Taxi Company Borough',
#        'Taxi Pick Up Location', 'Bridge Highway Name',
#        'Bridge Highway Direction', 'Road Ramp', 'Bridge Highway Segment',
# ...

# %%
df.isnull().sum()
# Out:
# Unique Key                              0
# Created Date                            0
# Closed Date                         59331
# Agency                                  0
# Agency Name                             0
# Complaint Type                          0
# Descriptor                           5540
# Location Type                      574411
# Incident Zip                       123025
# Incident Address                   382336
# Street Name                        382553
# Cross Street 1                     385546
# Cross Street 2                     394045
# Intersection Street 1             1430866
# Intersection Street 2             1430842
# Address Type                        52218
# City                               121815
# Landmark                          1781072
# Facility Type                     1555074
# Status                                  0
# Due Date                          1264395
# Resolution Action Updated Date      14187
# ...

# %%
df.describe()
# Out:
#          Unique Key  X Coordinate (State Plane)  Y Coordinate (State Plane)  \
# count  1.783133e+06                1.651563e+06                1.651563e+06
# mean   1.426476e+07                1.005578e+06                2.058625e+05
# std    8.691262e+05                2.269716e+04                3.184174e+04
# min    1.281778e+07                9.133570e+05                1.210320e+05
# 25%    1.342638e+07                9.939220e+05                1.821100e+05
# 50%    1.430104e+07                1.004849e+06                2.027900e+05
# 75%    1.502895e+07                1.017848e+06                2.365250e+05
# max    2.127794e+07                1.067279e+06                2.718760e+05
#
#            Latitude     Longitude
# count  1.651563e+06  1.651563e+06
# mean   4.073167e+01 -7.392301e+01
# std    8.739981e-02  8.185135e-02
# min    4.049863e+01 -7.425494e+01
# 25%    4.066648e+01 -7.396514e+01
# 50%    4.072323e+01 -7.392567e+01
# 75%    4.081584e+01 -7.387874e+01
# ...

# %%
# Now we count the City with the highest complaint
df['City'].value_counts()
# Out:
# BROOKLYN           524205
# BRONX              334612
# NEW YORK           332142
# STATEN ISLAND       86465
# JAMAICA             46131
#                     ...
# WESBURY                 1
# NEWYORK                 1
# NORTH TONAWANDA         1
# LIC                     1
# SAN BERNARDINO          1
# Name: City, Length: 720, dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1783133 entries, 0 to 1783132
# Data columns (total 52 columns):
# Unique Key                        int64
# Created Date                      object
# Closed Date                       object
# Agency                            object
# Agency Name                       object
# Complaint Type                    object
# Descriptor                        object
# Location Type                     object
# Incident Zip                      object
# Incident Address                  object
# Street Name                       object
# Cross Street 1                    object
# Cross Street 2                    object
# Intersection Street 1             object
# Intersection Street 2             object
# Address Type                      object
# City                              object
# Landmark                          object
# Facility Type                     object
# Status                            object
# ...

# %%
# Count of non-null values for every column  
df_columns = list(df.columns)
df[df_columns].count()
# Out:
# Unique Key                        1783133
# Created Date                      1783133
# Closed Date                       1723802
# Agency                            1783133
# Agency Name                       1783133
# Complaint Type                    1783133
# Descriptor                        1777593
# Location Type                     1208722
# Incident Zip                      1660108
# Incident Address                  1400797
# Street Name                       1400580
# Cross Street 1                    1397587
# Cross Street 2                    1389088
# Intersection Street 1              352267
# Intersection Street 2              352291
# Address Type                      1730915
# City                              1661318
# Landmark                             2061
# Facility Type                      228059
# Status                            1783133
# Due Date                           518738
# Resolution Action Updated Date    1768946
# ...

# %%
# some columns are removed due to lots of missing data and not useful to this analysis

df_col_rmv = ['Incident Address', 'Street Name', 'Cross Street 1', 'Cross Street 2',
               'Intersection Street 1', 'Intersection Street 2', 'Landmark', 'Facility Type',
               'Due Date', 'Resolution Action Updated Date','Community Board', 'X Coordinate (State Plane)',
               'Y Coordinate (State Plane)', 'Park Facility Name', 'Park Borough', 'School Name',
               'School Number', 'School Region', 'School Code', 'School Phone Number', 'School Address',
               'School City', 'School State', 'School Zip', 'School Not Found', 'School or Citywide Complaint',
               'Vehicle Type', 'Taxi Company Borough', 'Taxi Pick Up Location', 'Bridge Highway Name',
               'Bridge Highway Direction', 'Road Ramp', 'Bridge Highway Segment', 'Garage Lot Name',
               'Ferry Direction', 'Ferry Terminal Name','Address Type', 'Agency Name', 'Descriptor', 'Location','Location Type']

# %%
df.drop(df_col_rmv, inplace=True, axis=1)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1783133 entries, 0 to 1783132
# Data columns (total 11 columns):
# Unique Key        int64
# Created Date      object
# Closed Date       object
# Agency            object
# Complaint Type    object
# Incident Zip      object
# City              object
# Status            object
# Borough           object
# Latitude          float64
# Longitude         float64
# dtypes: float64(2), int64(1), object(8)
# memory usage: 149.6+ MB

# %%
df
# Out:
#          Unique Key            Created Date             Closed Date Agency  \
# 0          12822544  01/01/2009 12:00:00 AM  01/07/2009 12:00:00 AM    HPD
# 1          12818524  01/01/2009 12:00:00 AM                     NaN  DOHMH
# 2          12823061  01/01/2009 12:00:00 AM  01/01/2009 12:00:00 AM    DOT
# 3          12823062  01/01/2009 12:00:00 AM  01/01/2009 12:00:00 AM    DOT
# 4          12823063  01/01/2009 12:00:00 AM  01/01/2009 12:00:00 AM    DOT
# ...             ...                     ...                     ...    ...
# 1783128    15481288  12/11/2009 12:00:00 AM  12/18/2009 12:00:00 AM    HPD
# 1783129    15348603  11/22/2009 12:00:00 AM  12/18/2009 12:00:00 AM    HPD
# 1783130    15056076  10/13/2009 12:00:00 AM  11/16/2009 12:00:00 AM    HPD
# 1783131    12981671  01/21/2009 12:00:00 AM  06/24/2011 12:00:00 AM    DPR
# 1783132    14818914  09/09/2009 12:00:00 AM  07/13/2011 12:00:00 AM    DCA
#
#                    Complaint Type Incident Zip      City   Status  \
# ...

# %%
df['Status'].unique()
# Out:
# array(['Closed', 'Pending', 'Open', 'Assigned', 'Draft', 'Started',
#        'Unspecified'], dtype=object)

# %%
df['Borough'].unique()
# Out:
# array(['Unspecified', 'QUEENS', 'BROOKLYN', 'MANHATTAN', 'BRONX',
#        'STATEN ISLAND'], dtype=object)

# %%
df['Longitude'].unique()
# Out:
# array([-73.95806621, -73.92181787, -74.01682221, ..., -73.82348679,
#        -73.928574  , -73.82256432])

# %%
df['Latitude'].unique()
# Out:
# array([40.6566213 , 40.76889609, 40.63534465, ..., 40.68187725,
#        40.55208216, 40.76704582])

# %%
df['Agency'].unique()
# Out:
# array(['HPD', 'DOHMH', 'DOT', 'NYPD', 'TLC', 'DOITT', 'DPR', 'DCA',
#        'DSNY', 'DOE', 'DOB', 'DEP', 'DFTA', '3-1-1', 'DOF'], dtype=object)

# %%
df['Complaint Type'].unique()
# Out:
# array(['HEATING', 'Smoking', 'Traffic Signal Condition', 'NONCONST',
#        'PLUMBING', 'Noise - Commercial', 'Blocked Driveway',
#        'PAINT - PLASTER', 'GENERAL CONSTRUCTION', 'ELECTRIC', 'APPLIANCE',
#        'Taxi Complaint', 'Noise - Vehicle', 'Street Light Condition',
#        'Public Payphone Complaint', 'Damaged Tree', 'Dead Tree',
#        'Noise - Street/Sidewalk', 'Sidewalk Condition',
#        'Non-Residential Heat', 'Maintenance or Facility',
#        'For Hire Vehicle Complaint', 'Street Condition', 'CONSTRUCTION',
#        'Broken Muni Meter', 'Disorderly Youth', 'Indoor Air Quality',
#        'Drinking', 'Consumer Complaint', 'Derelict Vehicle',
#        'Food Poisoning', 'Rodent', 'Violation of Park Rules',
#        'Taxi Compliment', 'Missed Collection (All Materials)',
#        'Other Enforcement', 'Sanitation Condition', 'Snow',
#        'Teaching/Learning/Instruction', 'Vending', 'Food Establishment',
# ...

# %%
df['Incident Zip'].unique()
# Out:
# array(['11225', '11102', '11220', ..., '33901', '77387-8339', 'FLORIDA'],
#       dtype=object)

# %%
df['City'].unique()
# Out:
# array(['BROOKLYN', 'ASTORIA', 'OZONE PARK', 'WOODSIDE', 'NEW YORK',
#        'BRONX', 'STATEN ISLAND', 'ELMHURST', 'SUNNYSIDE', 'CORONA',
#        'ARVERNE', 'MASPETH', 'WOODHAVEN', 'JAMAICA', 'HOLLIS',
#        'QUEENS VILLAGE', 'FLUSHING', 'COLLEGE POINT', 'RIDGEWOOD',
#        'ROCKAWAY PARK', 'LONG ISLAND CITY', nan, 'FOREST HILLS',
#        'JACKSON HEIGHTS', 'RICHMOND HILL', 'SOUTH OZONE PARK',
#        'MIDDLE VILLAGE', 'SOUTH RICHMOND HILL', 'REGO PARK', 'BAYSIDE',
#        'HOWARD BEACH', 'KEW GARDENS', 'FAR ROCKAWAY', 'WHITESTONE',
#        'SPRINGFIELD GARDENS', 'SAINT ALBANS', 'EAST ELMHURST', 'ROSEDALE',
#        'CAMBRIA HEIGHTS', 'FRESH MEADOWS', 'GLEN OAKS', 'HOBOKEN',
#        'LITTLE NECK', 'CEDAR KNOLLF', 'WOODMERE', 'OAKLAND GARDENS',
#        'BELLEROSE', 'NORFOLK', 'FLORAL PARK', 'WHITE PLAINS', 'NY',
#        'CLEVELAND', 'JACKSONVILLE', 'ATLANTA', 'NEW HYDE PARK',
#        'LONG ISLAND', 'QUEENS', 'WING FARMINGDALE', 'ROCKVILLE',
# ...

# %% [markdown]
# ## Handling Missing Data

# %%
def correct_zip(zip_code):
    try:
        zip_code = int(float(zip_code))
    except:
        try:
            zip_code = int(float(zip_code.split('-')[0]))
        except:
            return np.nan
    if zip_code < 10000 or zip_code > 19999:
        return np.nan
    else:
        return str(zip_code)

# %%
# Apply correct_zip function to clean Incident Zip data
df['Incident Zip'] = df['Incident Zip'].apply(correct_zip)

# %%
df['Incident Zip'].unique()
# Out:
# array(['11225', '11102', '11220', '11201', '11235', '11417', '11237',
#        '11377', '10028', '10467', '11226', '11208', '10301', '11106',
#        '10010', '11212', '10013', '11203', '11218', '10457', '11221',
#        '10031', '10065', '10473', '10460', '10462', '11373', '10024',
#        '10027', '10453', '10463', '11222', '10459', '11213', '11207',
#        '10468', '11206', '10458', '10040', '11104', '11205', '10456',
#        '10452', '10472', '10466', '10030', '10034', '10003', '10474',
#        '11368', '10009', '11210', '10455', '11209', '10039', '10035',
#        '11232', '11692', '11378', '11421', '11435', '10451', '11423',
#        '11216', '11427', '11355', '10033', '10032', '11233', '11236',
#        '11356', '11215', '10454', '10036', '10012', '11211', '10475',
#        '11385', '11428', '10026', '10014', '11230', '11694', '10029',
#        '11204', '10461', '11367', '11101', nan, '11238', '10023', '10011',
# ...

# %%
df=df.replace("Unspecified",np.NaN)

# %%
df=df.replace("UNKNOWN",np.NaN)

# %%
df.dropna(how='all')
df
# Out:
#          Unique Key            Created Date             Closed Date Agency  \
# 0          12822544  01/01/2009 12:00:00 AM  01/07/2009 12:00:00 AM    HPD
# 1          12818524  01/01/2009 12:00:00 AM                     NaN  DOHMH
# 2          12823061  01/01/2009 12:00:00 AM  01/01/2009 12:00:00 AM    DOT
# 3          12823062  01/01/2009 12:00:00 AM  01/01/2009 12:00:00 AM    DOT
# 4          12823063  01/01/2009 12:00:00 AM  01/01/2009 12:00:00 AM    DOT
# ...             ...                     ...                     ...    ...
# 1783128    15481288  12/11/2009 12:00:00 AM  12/18/2009 12:00:00 AM    HPD
# 1783129    15348603  11/22/2009 12:00:00 AM  12/18/2009 12:00:00 AM    HPD
# 1783130    15056076  10/13/2009 12:00:00 AM  11/16/2009 12:00:00 AM    HPD
# 1783131    12981671  01/21/2009 12:00:00 AM  06/24/2011 12:00:00 AM    DPR
# 1783132    14818914  09/09/2009 12:00:00 AM  07/13/2011 12:00:00 AM    DCA
#
# ...

# %%
df['City'].unique()
# Out:
# array(['BROOKLYN', 'ASTORIA', 'OZONE PARK', 'WOODSIDE', 'NEW YORK',
#        'BRONX', 'STATEN ISLAND', 'ELMHURST', 'SUNNYSIDE', 'CORONA',
#        'ARVERNE', 'MASPETH', 'WOODHAVEN', 'JAMAICA', 'HOLLIS',
#        'QUEENS VILLAGE', 'FLUSHING', 'COLLEGE POINT', 'RIDGEWOOD',
#        'ROCKAWAY PARK', 'LONG ISLAND CITY', nan, 'FOREST HILLS',
#        'JACKSON HEIGHTS', 'RICHMOND HILL', 'SOUTH OZONE PARK',
#        'MIDDLE VILLAGE', 'SOUTH RICHMOND HILL', 'REGO PARK', 'BAYSIDE',
#        'HOWARD BEACH', 'KEW GARDENS', 'FAR ROCKAWAY', 'WHITESTONE',
#        'SPRINGFIELD GARDENS', 'SAINT ALBANS', 'EAST ELMHURST', 'ROSEDALE',
#        'CAMBRIA HEIGHTS', 'FRESH MEADOWS', 'GLEN OAKS', 'HOBOKEN',
#        'LITTLE NECK', 'CEDAR KNOLLF', 'WOODMERE', 'OAKLAND GARDENS',
#        'BELLEROSE', 'NORFOLK', 'FLORAL PARK', 'WHITE PLAINS', 'NY',
#        'CLEVELAND', 'JACKSONVILLE', 'ATLANTA', 'NEW HYDE PARK',
#        'LONG ISLAND', 'QUEENS', 'WING FARMINGDALE', 'ROCKVILLE',
# ...

# %%
df['Status'].unique()
# Out:
# array(['Closed', 'Pending', 'Open', 'Assigned', 'Draft', 'Started', nan],
#       dtype=object)

# %%
df.dropna(subset=['Status', 'City','Borough'])
# Out:
#          Unique Key            Created Date             Closed Date Agency  \
# 1          12818524  01/01/2009 12:00:00 AM                     NaN  DOHMH
# 2          12823061  01/01/2009 12:00:00 AM  01/01/2009 12:00:00 AM    DOT
# 3          12823062  01/01/2009 12:00:00 AM  01/01/2009 12:00:00 AM    DOT
# 4          12823063  01/01/2009 12:00:00 AM  01/01/2009 12:00:00 AM    DOT
# 29         12818298  01/01/2009 12:00:00 AM  01/01/2009 12:00:00 AM   NYPD
# ...             ...                     ...                     ...    ...
# 1783124    16141392  07/22/2009 12:00:00 AM  03/04/2010 12:00:00 AM    DOB
# 1783125    14985222  10/02/2009 12:00:00 AM  10/07/2009 12:00:00 AM   DSNY
# 1783126    15540492  12/18/2009 12:00:00 AM  08/20/2010 12:00:00 AM    DOB
# 1783131    12981671  01/21/2009 12:00:00 AM  06/24/2011 12:00:00 AM    DPR
# 1783132    14818914  09/09/2009 12:00:00 AM  07/13/2011 12:00:00 AM    DCA
#
# ...

# %%
df.dropna(inplace=True)
df
# Out:
#          Unique Key            Created Date             Closed Date Agency  \
# 2          12823061  01/01/2009 12:00:00 AM  01/01/2009 12:00:00 AM    DOT
# 3          12823062  01/01/2009 12:00:00 AM  01/01/2009 12:00:00 AM    DOT
# 4          12823063  01/01/2009 12:00:00 AM  01/01/2009 12:00:00 AM    DOT
# 29         12818298  01/01/2009 12:00:00 AM  01/01/2009 12:00:00 AM   NYPD
# 30         12818299  01/01/2009 12:00:00 AM  01/01/2009 12:00:00 AM   NYPD
# ...             ...                     ...                     ...    ...
# 1783124    16141392  07/22/2009 12:00:00 AM  03/04/2010 12:00:00 AM    DOB
# 1783125    14985222  10/02/2009 12:00:00 AM  10/07/2009 12:00:00 AM   DSNY
# 1783126    15540492  12/18/2009 12:00:00 AM  08/20/2010 12:00:00 AM    DOB
# 1783131    12981671  01/21/2009 12:00:00 AM  06/24/2011 12:00:00 AM    DPR
# 1783132    14818914  09/09/2009 12:00:00 AM  07/13/2011 12:00:00 AM    DCA
#
# ...

# %%
import datetime

# %%
df['Created Date']
# Out:
# 2          01/01/2009 12:00:00 AM
# 3          01/01/2009 12:00:00 AM
# 4          01/01/2009 12:00:00 AM
# 29         01/01/2009 12:00:00 AM
# 30         01/01/2009 12:00:00 AM
#                     ...
# 1783124    07/22/2009 12:00:00 AM
# 1783125    10/02/2009 12:00:00 AM
# 1783126    12/18/2009 12:00:00 AM
# 1783131    01/21/2009 12:00:00 AM
# 1783132    09/09/2009 12:00:00 AM
# Name: Created Date, Length: 926853, dtype: object

# %%
df['Closed Date']
# Out:
# 2          01/01/2009 12:00:00 AM
# 3          01/01/2009 12:00:00 AM
# 4          01/01/2009 12:00:00 AM
# 29         01/01/2009 12:00:00 AM
# 30         01/01/2009 12:00:00 AM
#                     ...
# 1783124    03/04/2010 12:00:00 AM
# 1783125    10/07/2009 12:00:00 AM
# 1783126    08/20/2010 12:00:00 AM
# 1783131    06/24/2011 12:00:00 AM
# 1783132    07/13/2011 12:00:00 AM
# Name: Closed Date, Length: 926853, dtype: object

# %%
df = df[(df['Latitude'].notnull()) & (df['Longitude'].notnull()) & (df['Closed Date'].notnull())]

# %%
import datetime

# %%
pd.options.display.max_columns = None

# %%
df['Created Date']=pd.to_datetime(df['Created Date'])

# %%
df['Closed Date'].replace('', np.nan, inplace=True)

# %%
df.dropna(subset=['Closed Date'], inplace=True)

# %%
pd.Timestamp.min
# Out:
# Timestamp('1677-09-21 00:12:43.145225')

# %%
pd.Timestamp.max
# Out:
# Timestamp('2262-04-11 23:47:16.854775807')

# %%
 pd.Timestamp.max - pd.Timestamp.min
# Out:
# datetime.timedelta(days=213503, seconds=84873, microseconds=709550)

# %%
df['Closed Date'] = pd.to_datetime(df['Closed Date'], errors='coerce')

# %%
df['Closed Date']=pd.to_datetime(df['Closed Date'])

# %%
df["Request_Closing_Time"] = df["Closed Date"] - df["Created Date"]

# %%
df['Request_Closing_Time'].describe()
# Out:
# count                     926852
# mean     16 days 18:08:40.906469
# std      71 days 06:29:33.636974
# min        -25640 days +00:00:00
# 25%              0 days 00:00:00
# 50%              1 days 00:00:00
# 75%              9 days 00:00:00
# max           2745 days 00:00:00
# Name: Request_Closing_Time, dtype: object

# %%
df
# Out:
#          Unique Key Created Date Closed Date Agency  \
# 2          12823061   2009-01-01  2009-01-01    DOT
# 3          12823062   2009-01-01  2009-01-01    DOT
# 4          12823063   2009-01-01  2009-01-01    DOT
# 29         12818298   2009-01-01  2009-01-01   NYPD
# 30         12818299   2009-01-01  2009-01-01   NYPD
# ...             ...          ...         ...    ...
# 1783124    16141392   2009-07-22  2010-03-04    DOB
# 1783125    14985222   2009-10-02  2009-10-07   DSNY
# 1783126    15540492   2009-12-18  2010-08-20    DOB
# 1783131    12981671   2009-01-21  2011-06-24    DPR
# 1783132    14818914   2009-09-09  2011-07-13    DCA
#
#                         Complaint Type Incident Zip          City  Status  \
# 2             Traffic Signal Condition        11220      BROOKLYN  Closed
# 3             Traffic Signal Condition        11201      BROOKLYN  Closed
# 4             Traffic Signal Condition        11235      BROOKLYN  Closed
# ...

# %%
#View Prcoessing Time data that is negative
df[df['Request_Closing_Time']<datetime.timedelta(0,0,0)].head(3)
# Out:
#       Unique Key Created Date Closed Date Agency          Complaint Type  \
# 3110    12837431   2009-01-02  2008-12-26    DOT  Street Light Condition
# 3111    12837432   2009-01-02  2008-12-26    DOT  Street Light Condition
# 3112    12837433   2009-01-02  2008-12-26    DOT  Street Light Condition
#
#      Incident Zip           City   Status Borough   Latitude  Longitude  \
# 3110        11694  ROCKAWAY PARK  Pending  QUEENS  40.581184 -73.825089
# 3111        11434        JAMAICA  Pending  QUEENS  40.677842 -73.780260
# 3112        11412   SAINT ALBANS  Pending  QUEENS  40.697729 -73.757633
#
#      Request_Closing_Time
# 3110              -7 days
# 3111              -7 days
# 3112              -7 days

# %%
 #Remove all data from df that have negative Processing Time
df = df[df['Request_Closing_Time']>=datetime.timedelta(0,0,0)]

# %%
df
# Out:
#          Unique Key Created Date Closed Date Agency  \
# 2          12823061   2009-01-01  2009-01-01    DOT
# 3          12823062   2009-01-01  2009-01-01    DOT
# 4          12823063   2009-01-01  2009-01-01    DOT
# 29         12818298   2009-01-01  2009-01-01   NYPD
# 30         12818299   2009-01-01  2009-01-01   NYPD
# ...             ...          ...         ...    ...
# 1783124    16141392   2009-07-22  2010-03-04    DOB
# 1783125    14985222   2009-10-02  2009-10-07   DSNY
# 1783126    15540492   2009-12-18  2010-08-20    DOB
# 1783131    12981671   2009-01-21  2011-06-24    DPR
# 1783132    14818914   2009-09-09  2011-07-13    DCA
#
#                         Complaint Type Incident Zip          City  Status  \
# 2             Traffic Signal Condition        11220      BROOKLYN  Closed
# 3             Traffic Signal Condition        11201      BROOKLYN  Closed
# 4             Traffic Signal Condition        11235      BROOKLYN  Closed
# ...

# %%
#Count of non-null values for every column 
df_columns = list(df.columns)
df[df_columns].count()
# Out:
# Unique Key              912089
# Created Date            912089
# Closed Date             912089
# Agency                  912089
# Complaint Type          912089
# Incident Zip            912089
# City                    912089
# Status                  912089
# Borough                 912089
# Latitude                912089
# Longitude               912089
# Request_Closing_Time    912089
# dtype: int64

# %% [markdown]
# ### Visualizations

# %%
borough = df.groupby('Borough')
borough.size().plot(kind='bar', figsize=(12,6), title=('Incidents by Borough'));

# %%
# Visualization of incidents by Agency
agency = df.groupby('Agency')
agency.size().plot(kind='bar', figsize=(12,6), title=('Incidents calls per Agency'));

# %%
#Visualization of numnber of incidents in each Borough by Agency
agency_borough = df.groupby(['Agency','Borough']).size().unstack()
agency_borough.plot(kind='bar', title='Total Inicidents in each Borough by Agency', figsize=(15,7));

# %%
#Visualization of top Agencies with most incidents per borough
col_number = 2
row_number = 3
fig, axes = plt.subplots(row_number,col_number, figsize=(12,12))

for i, (label,col) in enumerate(agency_borough.iteritems()):
    ax = axes[int(i/col_number), i%col_number]
    col = col.sort_values(ascending=True)[:5]
    col.plot(kind='barh', ax=ax)
    ax.set_title(label)
    
plt.tight_layout()

# %%
# Create Bar plot for complain type to check frequency in Complain Type
df['Complaint Type'].value_counts().plot(kind="barh", color=list('rgbkymc'), alpha=0.7, figsize=(15,20))
plt.show()

# %% [markdown]
# ## Order the complaint types based on the average ‘Request_Closing_Time’, grouping them for different locations.

# %%
import math

# %%
#Function to convert TimeDelta in Hour
def toHr(timeDel):
    days = timeDel.days
    hours = round(timeDel.seconds/3600, 2)
    result = (days * 24) + hours
    #print(days)
    #print(hours)
    return result
    #return round(pd.Timedelta(timeDel).seconds / 3600, 2)

# %%
df['City'].isnull().sum()
# Out:
# 0

# %%
df
# Out:
#          Unique Key Created Date Closed Date Agency  \
# 2          12823061   2009-01-01  2009-01-01    DOT
# 3          12823062   2009-01-01  2009-01-01    DOT
# 4          12823063   2009-01-01  2009-01-01    DOT
# 29         12818298   2009-01-01  2009-01-01   NYPD
# 30         12818299   2009-01-01  2009-01-01   NYPD
# ...             ...          ...         ...    ...
# 1783124    16141392   2009-07-22  2010-03-04    DOB
# 1783125    14985222   2009-10-02  2009-10-07   DSNY
# 1783126    15540492   2009-12-18  2010-08-20    DOB
# 1783131    12981671   2009-01-21  2011-06-24    DPR
# 1783132    14818914   2009-09-09  2011-07-13    DCA
#
#                         Complaint Type Incident Zip          City  Status  \
# 2             Traffic Signal Condition        11220      BROOKLYN  Closed
# 3             Traffic Signal Condition        11201      BROOKLYN  Closed
# 4             Traffic Signal Condition        11235      BROOKLYN  Closed
# ...

# %%
df = df.copy()

# %%
df.loc[:,'Request_Closing_In_Hr'] = df['Request_Closing_Time'].apply(toHr)

# %%
df['Request_Closing_In_Hr']
# Out:
# 2              0.0
# 3              0.0
# 4              0.0
# 29             0.0
# 30             0.0
#             ...
# 1783124     5400.0
# 1783125      120.0
# 1783126     5880.0
# 1783131    21216.0
# 1783132    16128.0
# Name: Request_Closing_In_Hr, Length: 912089, dtype: float64

# %%
# Group them for City (location) first and Complain Type in that
df_grouped = df.groupby(['City', 'Complaint Type'])
df_grouped

# %%
df_mean = df_grouped.mean()['Request_Closing_In_Hr']
df_mean
# Out:
# City      Complaint Type
# ARVERNE   Air Quality                  192.000000
#           Animal in a Park              24.000000
#           Asbestos                       0.000000
#           BEST/Site Safety              24.000000
#           Bike/Roller/Skate Chronic      0.000000
#                                           ...
# WOODSIDE  Vending                        0.000000
#           Violation of Park Rules      113.142857
#           Water Conservation           168.000000
#           Water Quality                385.333333
#           Water System                 140.925490
# Name: Request_Closing_In_Hr, Length: 4201, dtype: float64

# %% [markdown]
# ##  Perform a statistical test for the following:

# %%
import scipy.stats as stats
from math import sqrt

# %%
df['Complaint Type'].value_counts()
# Out:
# Street Condition                 95467
# General Construction/Plumbing    60588
# Street Light Condition           60558
# Water System                     58462
# Blocked Driveway                 52161
#                                  ...
# Calorie Labeling                     3
# Tattooing                            3
# Summer Camp                          3
# Trapping Pigeon                      1
# Window Guard                         1
# Name: Complaint Type, Length: 138, dtype: int64

# %%
top5_complaints_type = df['Complaint Type'].value_counts()[:5]
top5_complaints_type
# Out:
# Street Condition                 95467
# General Construction/Plumbing    60588
# Street Light Condition           60558
# Water System                     58462
# Blocked Driveway                 52161
# Name: Complaint Type, dtype: int64

# %%
top5_complaints_type_names = top5_complaints_type.index
top5_complaints_type_names
# Out:
# Index(['Street Condition', 'General Construction/Plumbing',
#        'Street Light Condition', 'Water System', 'Blocked Driveway'],
#       dtype='object')

# %%
sample_data = df.loc[df['Complaint Type'].isin(top5_complaints_type_names), ['Complaint Type', 'Request_Closing_In_Hr']]
sample_data.head()
# Out:
#              Complaint Type  Request_Closing_In_Hr
# 30         Blocked Driveway                    0.0
# 266  Street Light Condition                  120.0
# 268  Street Light Condition                  120.0
# 287        Blocked Driveway                    0.0
# 288        Blocked Driveway                    0.0

# %%
top5_location = df['City'].value_counts()[:5]
top5_location
# Out:
# BROOKLYN         272274
# NEW YORK         185479
# BRONX            104835
# STATEN ISLAND     67643
# JAMAICA           31627
# Name: City, dtype: int64

# %%
top5_location_names = top5_location.index
top5_location_names
# Out:
# Index(['BROOKLYN', 'NEW YORK', 'BRONX', 'STATEN ISLAND', 'JAMAICA'], dtype='object')

# %%
sample_data_location_c_type = df.loc[(df['Complaint Type'].isin(top5_complaints_type_names)) & (df['City'].isin(top5_location_names)), ['Complaint Type', 'City']]
sample_data_location_c_type.head()
# Out:
#              Complaint Type      City
# 30         Blocked Driveway     BRONX
# 266  Street Light Condition     BRONX
# 268  Street Light Condition     BRONX
# 288        Blocked Driveway  BROOKLYN
# 304        Blocked Driveway  BROOKLYN

# %%
pd.crosstab(sample_data_location_c_type['Complaint Type'], sample_data_location_c_type['City'], margins=True)
# Out:
# City                           BRONX  BROOKLYN  JAMAICA  NEW YORK  \
# Complaint Type
# Blocked Driveway                8289     19902     1874      1794
# General Construction/Plumbing   5440     19219     1828     14818
# Street Condition                9786     28281     3326     18881
# Street Light Condition          4625     18664     2837      2482
# Water System                    8652     17305     1667      9760
# All                            36792    103371    11532     47735
#
# City                           STATEN ISLAND     All
# Complaint Type
# Blocked Driveway                        1805   33664
# General Construction/Plumbing           3038   44343
# Street Condition                       12292   72566
# Street Light Condition                  8599   37207
# Water System                            5633   43017
# All                                    31367  230797

# %%
ch2, p_value, df, exp_frq = stats.chi2_contingency(pd.crosstab(sample_data_location_c_type['Complaint Type'], sample_data_location_c_type['City']))

# %%
print(ch2)
print(p_value)
# Out:
# 24463.247506096854
# 0.0

# %%
#We can see pvalue is less than 0.05 so we reject null hypothesis means complain type and location is not independent.
